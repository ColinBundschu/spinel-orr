# %%
# type: ignore
import IPython
if 'IPython.extensions.autoreload' not in IPython.get_ipython().extension_manager.loaded:
    # %load_ext autoreload
    # %autoreload 2
import sys

sys.path.append('../..')
import visualization.echem.figures as figs

# %%
base_folder = '/mnt/c/Users/colin/Dropbox/School/PhD Research/2023 Co3O4 Paper/data'
figs.create_experimental_fig(base_folder, dpi=50)

# %%
base_folder = '/mnt/c/Users/colin/Dropbox/School/PhD Research/2023 Co3O4 Paper/data'
cv_data_filename = 'cv.xlsx'
rde_data_filename = 'rde.xlsx'
tafel_fig_filename = 'tafel_fig.png'
figs.create_S3_fig(base_folder, cv_data_filename, rde_data_filename, tafel_fig_filename, dpi=70)

# %%
figs.create_temperature_fig('/mnt/c/Users/colin/Dropbox/School/PhD Research/pt_study', dpi=80)

# %%
base_folder = '/mnt/c/Users/colin/Dropbox/School/PhD Research/2024_jonathan_core_shell/Kl_data'
cv_data_basename = 'JLR-6-X_levich.xlsx'
file_nums = [144, 145, 146, 150, 162]
figs.create_rde_fig(base_folder, file_nums, cv_data_basename)
# Out:
# JLR-6-144_levich  n_e_raw=3.11  n_e_corrected=3.54
# JLR-6-145_levich  n_e_raw=3.43  n_e_corrected=3.91
# JLR-6-146_levich  n_e_raw=3.41  n_e_corrected=3.89
# JLR-6-150_levich  n_e_raw=2.90  n_e_corrected=3.30
# JLR-6-162_levich  n_e_raw=3.08  n_e_corrected=3.50
